# %%
print("hello word")
# Out:
# hello word

# %%
print("ANANTA KHARISMA")
print("2605060037")
print("TEKNOLOGI INFORMASI")
# Out:
# ANANTA KHARISMA
# 2605060037
# TEKNOLOGI INFORMASI

# %%
x = 5
print(type(x))
# Out:
# <class 'int'>

# %%
x = 1
y = 2.8
z = 1j
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
x = 5
y = "john"
print(x)
print(y)
# Out:
# 5
# john
