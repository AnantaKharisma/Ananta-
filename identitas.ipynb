# %% [markdown]
# <a href="https://colab.research.google.com/github/AnantaKharisma/Ananta-/blob/main/identitas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Menampilkan judul program
print("===== DATA DIRI =====")

# Menyimpan data nama
print("nama = Ananta Kharisma")

# Menyimpan data NIM
print("nim = 2605060037")

# Menyimpan data tempat dan tanggal lahir
print("ttl = Magelang,12 September 2006")

# Menyimpan data alamat
print("alamat = Tempuksari Rt 21 Rw 07 Candisari,Secang,Kab.Magelang")

# Menyimpan data jenis kelamin
print("jenis_kelamin = Laki-laki")

# Menyimpan data hobi
print("hobi = Futsal")
# Out:
# ===== DATA DIRI =====
# nama = Ananta Kharisma
# nim = 2605060037
# ttl = Magelang,12 September 2006
# alamat = Tempuksari Rt 21 Rw 07 Candisari,Secang,Kab.Magelang
# jenis_kelamin = Laki-laki
# hobi = Futsal
